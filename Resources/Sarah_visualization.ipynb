# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# CSV into dataframe
csv = "../output/result2.csv"
result_df = pd.read_csv(csv)
result_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                 Movie_Title  IMDB Film Rating  \
# 0           0             0  10 Things I Hate About You  0.73       PG-13
# 1           1             1                          12  0.77       PG-13
# 2           2             2              12 and Holding  0.76           R
# 3           3             3                  12 Monkeys  0.77       TV-14
# 4           4             4            12 Years a Slave  0.81           R
#
#       Released  Runtime                                        Genre  \
# 0  31 Mar 1999   97 min                       Comedy, Drama, Romance
# 1  20 Sep 2007  159 min                  Crime, Drama, Thriller, War
# 2  07 Jul 2006   94 min                                        Drama
# 3  16 Jan 2015   42 min  Adventure, Drama, Mystery, Sci-Fi, Thriller
# 4  08 Nov 2013  134 min                    Biography, Drama, History
#
#                         Movie_Links  shit  ...  dick pussy cock bastard  \
# ...

# %%
# Plot the Bad Word Count vs Rating and save figure
plt.scatter(x=result_df['IMDB'], y=result_df['total_bad_words'])
plt.title('Bad Word Count Vs. Rating')
plt.ylabel('Bad Word Count')
plt.xlabel('IMDB Rating')
plt.grid()
plt.savefig('../Figures/Count_v_Rating.png')
plt.show()

# %%
# Group average Bad Word Count by year
df_group = result_df.groupby(by='Year').mean()
df_group.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1  IMDB  total_bad_words  Runtime_minutes  \
# Year
# 1915       321.0         321.0  0.73              7.0              1.0
# 1931       484.5         484.5  0.74              8.0             79.5
# 1932       210.0         210.0  0.75              0.0             93.5
# 1933       272.0         272.0  0.80              0.0             68.0
# 1934       447.5         447.5  0.81              0.0            105.0
#
#       bad_word_frequency
# Year
# 1915            0.140000
# 1931           46.835000
# 1932                 inf
# 1933                 inf
# 1934                 inf

# %%
# Reduce dataframe to year and average bad word count
df_group_bad = df_group['total_bad_words']

# %%
# Plot average bad word count by year and save figure
df_group_bad.plot()
plt.title('Mean Bad Word Count by Year')
plt.ylabel('Bad Word Count')
plt.grid()
plt.savefig('../Figures/Count_by_Year.png')
plt.show()
