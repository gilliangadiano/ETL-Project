# %%
import numpy as np
import pandas as pd
import requests
import json
# New Dependency! Use this to pretty print the JSON
# https://docs.python.org/3/library/pprint.html
from pprint import pprint

# %%
file_two = "../output/result.csv"
df3 = pd.read_csv(file_two, encoding="ISO-8859-1")
df3.head()
# Out:
#    Unnamed: 0                 Movie_Title  IMDB Film Rating     Released  \
# 0           0  10 Things I Hate About You  0.73       PG-13  31 Mar 1999
# 1           1                          12  0.77       PG-13  20 Sep 2007
# 2           2              12 and Holding  0.76           R  07 Jul 2006
# 3           3                  12 Monkeys  0.77       TV-14  16 Jan 2015
# 4           4            12 Years a Slave  0.81           R  08 Nov 2013
#
#    Runtime                                        Genre  \
# 0   97 min                       Comedy, Drama, Romance
# 1  159 min                  Crime, Drama, Thriller, War
# 2   94 min                                        Drama
# 3   42 min  Adventure, Drama, Mystery, Sci-Fi, Thriller
# 4  134 min                    Biography, Drama, History
#
#                         Movie_Links  shit  fuck  damn  bitch  asshole  ass  \
# 0  /10-Things-I-Hate-About-You.html   8.0   2.0   3.0    5.0      3.0  7.0
# 1                          /12.html   1.0   0.0   1.0    0.0      1.0  0.0
# 2              /12-and-Holding.html  10.0   4.0   3.0    1.0      5.0  4.0
# 3                  /12-Monkeys.html   4.0   5.0   2.0    2.0      1.0  3.0
# 4            /12-Years-a-Slave.html   0.0   0.0  12.0    1.0      0.0  0.0
#
#    dick  pussy  cock  bastard  douche  total_words
# 0   2.0    1.0   0.0      0.0     0.0      19152.0
# 1   0.0    1.0   0.0      2.0     0.0      14144.0
# 2   0.0    7.0   0.0      1.0     0.0      18999.0
# 3   0.0    1.0   0.0      2.0     0.0      32272.0
# 4   0.0    0.0   0.0      3.0     0.0      31014.0
